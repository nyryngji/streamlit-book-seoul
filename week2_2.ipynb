# %%
import requests
import json
import pandas as pd

api = '427879525a616d7937336c504c6947'

url = 'http://openapi.seoul.go.kr:8088/{}/json/bigCmpBjdongMgmInfo/1/500'.format(api)
# http://openapi.seoul.go.kr:8088/(인증키)/xml/tbLnOpendataRtmsV/1/5/
response = requests.get(url)
content = response.json()
content
# Out:
# {'bigCmpBjdongMgmInfo': {'list_total_count': 2355,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'SIGUNGU_CD': '11680',
#     'BJDONG_CD': '10600',
#     'HJDONG_CD': '675',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강남구',
#     'BJDONG_NM': '대치동',
#     'HJDONG_NM': '개포3동',
#     'APPLY_STRT_DAY': '20221223',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11680',
#     'BJDONG_CD': '11400',
#     'HJDONG_CD': '675',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강남구',
#     'BJDONG_NM': '일원동',
#     'HJDONG_NM': '개포3동',
#     'APPLY_STRT_DAY': '20221223',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11680',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '675',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강남구',
#     'BJDONG_NM': '개포동',
#     'HJDONG_NM': '개포3동',
#     'APPLY_STRT_DAY': '20221223',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11740',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '525',
# ...

# %%
con = content['bigCmpBjdongMgmInfo']['row']
result = pd.DataFrame(con)
result.head()
# Out:
#   SIGUNGU_CD BJDONG_CD HJDONG_CD SIDO_NM SIGUNGU_NM BJDONG_NM HJDONG_NM  \
# 0      11680     10600       675   서울특별시        강남구       대치동      개포3동
# 1      11680     11400       675   서울특별시        강남구       일원동      개포3동
# 2      11680     10300       675   서울특별시        강남구       개포동      개포3동
# 3      11740     10300       525   서울특별시        강동구       상일동     상일제1동
# 4      11740     10300       526   서울특별시        강동구       상일동     상일제2동
#
#   APPLY_STRT_DAY APPLY_EXP_DAY
# 0       20221223      99991231
# 1       20221223      99991231
# 2       20221223      99991231
# 3       20210701      99991231
# 4       20210701      99991231

# %%
result[result['SIGUNGU_NM'] == '양천구']
# Out:
#     SIGUNGU_CD BJDONG_CD HJDONG_CD SIDO_NM SIGUNGU_NM BJDONG_NM HJDONG_NM  \
# 488      11470     10100       680   서울특별시        양천구       신정동      신정7동
#
#     APPLY_STRT_DAY APPLY_EXP_DAY
# 488       19890901      99991231

# %%
# 서울시 시간 평균 대기오염도 정보
api2 = '6a45684d74616d79363748754c4659'
url = 'http://openAPI.seoul.go.kr:8088/{}/json/TimeAverageAirQuality/1/100/20130615'.format(api2)
response = requests.get(url)
content = response.json()
content
# Out:
# {'TimeAverageAirQuality': {'list_total_count': 600,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'MSRDT': '201306152300',
#     'MSRSTE_NM': '동대문구',
#     'NO2': 0.023,
#     'O3': 0.018,
#     'CO': 0.3,
#     'SO2': 0.005,
#     'PM10': 33.0,
#     'PM25': 21.0},
#    {'MSRDT': '201306152300',
#     'MSRSTE_NM': '은평구',
#     'NO2': 0.026,
#     'O3': 0.017,
#     'CO': 0.5,
#     'SO2': 0.007,
#     'PM10': 37.0,
#     'PM25': 19.0},
#    {'MSRDT': '201306152300',
#     'MSRSTE_NM': '금천구',
#     'NO2': 0.035,
#     'O3': 0.01,
#     'CO': 0.3,
#     'SO2': 0.007,
#     'PM10': 37.0,
#     'PM25': 26.0},
#    {'MSRDT': '201306152300',
#     'MSRSTE_NM': '성동구',
#     'NO2': 0.033,
#     'O3': 0.013,
#     'CO': 0.3,
#     'SO2': 0.002,
#     'PM10': 30.0,
#     'PM25': 19.0},
#    {'MSRDT': '201306152300',
#     'MSRSTE_NM': '강동구',
#     'NO2': 0.029,
#     'O3': 0.023,
#     'CO': 0.4,
#     'SO2': 0.004,
#     'PM10': 23.0,
#     'PM25': 14.0},
# ...

# %%
con = content['TimeAverageAirQuality']['row']
result = pd.DataFrame(con)
result.head()
# Out:
#           MSRDT MSRSTE_NM    NO2     O3   CO    SO2  PM10  PM25
# 0  201306152300      동대문구  0.023  0.018  0.3  0.005  33.0  21.0
# 1  201306152300       은평구  0.026  0.017  0.5  0.007  37.0  19.0
# 2  201306152300       금천구  0.035  0.010  0.3  0.007  37.0  26.0
# 3  201306152300       성동구  0.033  0.013  0.3  0.002  30.0  19.0
# 4  201306152300       강동구  0.029  0.023  0.4  0.004  23.0  14.0
