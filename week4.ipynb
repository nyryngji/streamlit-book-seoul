# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt


total_df = pd.read_csv('seoul_real_estate.csv')

total_df['DEAL_YMD'] = pd.to_datetime(total_df['DEAL_YMD'],format="%Y-%m-%d")
total_df['month'] = total_df['DEAL_YMD'].dt.month
total_df['year'] = total_df['DEAL_YMD'].dt.year 

total_df['month'] = total_df['month'].astype('int')
total_df['year'] = total_df['year'].astype('int')

total_df = total_df[total_df['HOUSE_TYPE'] == '아파트']

# %%
month_dic = {}
for i in range(1,13):
    month_dic[str(i)+'월'] = i

filtered_month = total_df[total_df['month'] == month_dic['12월']]
filtered_month = filtered_month[filtered_month['year'] == 2023]
filtered_month = filtered_month[filtered_month['SGG_NM'] == '구로구']

filtered_month
# Out:
#        ACC_YEAR  SGG_CD SGG_NM  BJDONG_CD BJDONG_NM  LAND_GBN LAND_GBN_NM  \
# 10617      2024   11530    구로구      10800       오류동       1.0          대지
# 10724      2024   11530    구로구      11200        항동       1.0          대지
# 10870      2024   11530    구로구      10800       오류동       1.0          대지
# 10906      2024   11530    구로구      10600       고척동       1.0          대지
# 10985      2023   11530    구로구      10200       구로동       1.0          대지
# ...         ...     ...    ...        ...       ...       ...         ...
# 15261      2023   11530    구로구      10800       오류동       1.0          대지
# 15290      2023   11530    구로구      11200        항동       3.0          블럭
# 15336      2023   11530    구로구      10200       구로동       1.0          대지
# 15406      2023   11530    구로구      10200       구로동       1.0          대지
# 15419      2023   11530    구로구      10600       고척동       1.0          대지
#
#       BONBEON BUBEON        BLDG_NM  ... TOT_AREA  FLOOR  RIGHT_GBN  CNTL_YMD  \
# ...

# %%
mins_3 = filtered_month[['SGG_NM','BJDONG_NM','BLDG_NM','BLDG_AREA','OBJ_AMT']].sort_values(by='OBJ_AMT').head(3)
maxs_3 = filtered_month[['SGG_NM','BJDONG_NM','BLDG_NM','BLDG_AREA','OBJ_AMT']].sort_values(by='OBJ_AMT').tail(3)
# Out:
#       SGG_NM BJDONG_NM    BLDG_NM  BLDG_AREA  OBJ_AMT
# 14759    구로구      신도림동        대림2     134.99   128800
# 12081    구로구      신도림동  대림e-편한세상4      84.78   137000
# 13970    구로구      신도림동  대림e-편한세상4     152.07   165000

# %%
total_df.head()
# Out:
#    ACC_YEAR  SGG_CD SGG_NM  BJDONG_CD BJDONG_NM  LAND_GBN LAND_GBN_NM BONBEON  \
# 0      2024   11530    구로구      10600       고척동       1.0          대지    0328
# 1      2024   11380    은평구      10500       구산동       1.0          대지    0211
# 2      2024   11620    관악구      10100       봉천동       1.0          대지    1574
# 3      2024   11530    구로구      10200       구로동       1.0          대지    0415
# 4      2024   11680    강남구      10300       개포동       1.0          대지    1224
#
#   BUBEON      BLDG_NM  ... OBJ_AMT  BLDG_AREA  TOT_AREA  FLOOR  RIGHT_GBN  \
# 0   0000           양우  ...   43500      59.94      0.00    6.0        NaN
# 1   0002  뉴아름빌(211-2)  ...   25000      42.40     25.00    5.0        NaN
# 2   0001       생모리츠타운  ...   11700      22.24     30.66    7.0        NaN
# 3   0044          미라벨  ...   23000      29.39     18.00    2.0        NaN
# 4   0004      예가풍경채3차  ...   61000      37.43     22.00    3.0        NaN
#
# ...

# %%
total_df = pd.read_csv('seoul_real_estate.csv')
total_df['DEAL_YMD'] = pd.to_datetime(total_df['DEAL_YMD'],format="%Y-%m-%d")

total_df['month'] = total_df['DEAL_YMD'].dt.month
total_df['year'] = total_df['DEAL_YMD'].dt.year 

total_df['year+month'] = total_df['year'].astype('str') + '.' + total_df['month'].astype('str')

total_df.head()
# Out:
#    ACC_YEAR  SGG_CD SGG_NM  BJDONG_CD BJDONG_NM  LAND_GBN LAND_GBN_NM BONBEON  \
# 0      2024   11530    구로구      10600       고척동       1.0          대지    0328
# 1      2024   11380    은평구      10500       구산동       1.0          대지    0211
# 2      2024   11620    관악구      10100       봉천동       1.0          대지    1574
# 3      2024   11530    구로구      10200       구로동       1.0          대지    0415
# 4      2024   11680    강남구      10300       개포동       1.0          대지    1224
#
#   BUBEON      BLDG_NM  ... FLOOR  RIGHT_GBN    CNTL_YMD  BUILD_YEAR  \
# 0   0000           양우  ...   6.0        NaN  20240316.0      2000.0
# 1   0002  뉴아름빌(211-2)  ...   5.0        NaN  20240315.0      2018.0
# 2   0001       생모리츠타운  ...   7.0        NaN         NaN      2007.0
# 3   0044          미라벨  ...   2.0        NaN         NaN      2018.0
# 4   0004      예가풍경채3차  ...   3.0        NaN         NaN      2019.0
#
#    HOUSE_TYPE REQ_GBN  RDEALER_LAWDNM  month  year year+month
# ...

# %%
filtered_df = total_df[total_df['SGG_NM'] == '구로구']
df1 = filtered_df[filtered_df['HOUSE_TYPE'] == '아파트'].groupby('year+month').count().reset_index()
df1[['year+month','ACC_YEAR']]
# Out:
#   year+month  ACC_YEAR
# 0    2023.11        90
# 1    2023.12        87
# 2     2024.1       134
# 3     2024.2       104
# 4     2024.3        36

# %%
total_df.groupby('year+month').count()
# Out:
#             ACC_YEAR  SGG_CD  SGG_NM  BJDONG_CD  BJDONG_NM  LAND_GBN  \
# year+month
# 2023.11         4578    4578    4578       4578       4578      4355
# 2023.12         4805    4805    4805       4805       4805      4603
# 2024.1          5300    5300    5299       5300       5300      5105
# 2024.2          4270    4270    4270       4270       4270      4127
# 2024.3          1047    1047    1047       1047       1047      1012
#
#             LAND_GBN_NM  BONBEON  BUBEON  BLDG_NM  ...  TOT_AREA  FLOOR  \
# year+month                                         ...
# 2023.11            4355     4355    4355     4358  ...      4578   4578
# 2023.12            4603     4603    4603     4605  ...      4805   4805
# 2024.1             5105     5105    5105     5106  ...      5300   5300
# 2024.2             4127     4127    4127     4127  ...      4270   4270
# 2024.3             1012     1012    1012     1012  ...      1047   1047
#
# ...
